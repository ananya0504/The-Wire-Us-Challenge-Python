# %% [markdown]
# <a href="https://colab.research.google.com/github/ananya0504/The-Wire-Us-Challenge-Python/blob/master/Day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Grocrylist = ["Chocolate", "Milk", "Cereal"]
print(Grocrylist) #allitems
print(Grocrylist[0]) #first item
print(Grocrylist[-1]) #last item
print(Grocrylist[0:2]) #0 included, 2 not included
print(Grocrylist[:1]) #1 not included
print(Grocrylist[1:])

for x in Grocrylist:
  print(x)
# Out:
# ['Chocolate', 'Milk', 'Cereal']
# Chocolate
# Cereal
# ['Chocolate', 'Milk']
# ['Chocolate']
# ['Milk', 'Cereal']
# Chocolate
# Milk
# Cereal
