# %% [markdown]
# <a href="https://colab.research.google.com/github/ananya0504/The-Wire-Us-Challenge-Python/blob/master/Day7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("Enter a number:"))
d={x:x*x for x in range(1,n+1)}
print(d)
# Out:
# Enter a number:10
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}
