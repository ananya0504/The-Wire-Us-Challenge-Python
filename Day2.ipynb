# %% [markdown]
# <a href="https://colab.research.google.com/github/ananya0504/The-Wire-Us-Challenge-Python/blob/master/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter a number: "))
count = 0
while(num > 0):
    num //= 10
    count += 1

print("\n Number of digits in a given number = %d" %count )
# Out:
# Enter a number: 45678
#
#  Number of digits in a given number = 5
