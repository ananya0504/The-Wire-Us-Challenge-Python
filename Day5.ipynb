# %% [markdown]
# <a href="https://colab.research.google.com/github/ananya0504/The-Wire-Us-Challenge-Python/blob/master/Day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age=int(input("Enter your age: "))
if age >= 18 :
    print("You are eligible to cast a vote.")
else:
    print("There are still ",18-age," years left to be eligible!")
# Out:
# Enter your age: 12
# There are still  6  years left to be eligible!
