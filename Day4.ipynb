# %% [markdown]
# <a href="https://colab.research.google.com/github/ananya0504/The-Wire-Us-Challenge-Python/blob/master/Day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=int(input("Enter your age:"))
if x>=18:
  print("Eligible to vote")
else:
  print("Cannot vote, wait till you grow up!")
# Out:
# Enter your age:18
# Eligible to vote

# %%
x=int(input("Enter your age:"))
print("Eligible to vote") if x>=18 else print("Cannot vote, wait till you grow up!")
# Out:
# Enter your age:17
# Cannot vote, wait till you grow up!
